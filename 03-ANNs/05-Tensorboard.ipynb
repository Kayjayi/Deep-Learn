# %% [markdown]
# <a href="https://www.pieriandata.com"><img src="../Pierian_Data_Logo.PNG"></a>
# <strong><center>Copyright by Pierian Data Inc.</center></strong>
# <strong><center>Created by Jose Marcial Portilla.</center></strong>

# %% [markdown]
# # Tensorboard
#
# ---
# ---
#
# **NOTE: You must watch the corresponding video to understand this lecture. This notebook can't serve as a full guide. Please watch the video BEFORE posting questions to the QA forum.**
#
# ---
# ---
#
# Let's explore the built in data visualization capabilities that come with Tensorboard.
#
# Full official tutorial available here: https://www.tensorflow.org/tensorboard/get_started
#
# ## Data

# %%
import pandas as pd
import numpy as np

# %%
#df = pd.read_csv('../DATA/cancer_classification.csv')
df = pd.read_csv('cancer_classification.csv')

# %% [markdown]
# ### Train Test Split

# %%
X = df.drop('benign_0__mal_1',axis=1).values
y = df['benign_0__mal_1'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=101)

# %% [markdown]
# ### Scaling Data

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(X_train)
# Out:
# MinMaxScaler()

# %%
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Creating the Model

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation,Dropout

# %%
from tensorflow.keras.callbacks import EarlyStopping,TensorBoard

# %%
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25)

# %%
pwd
# Out:
# '/content'

# %% [markdown]
# ## Creating the Tensorboard Callback
#
# TensorBoard is a visualization tool provided with TensorFlow.
#
# This callback logs events for TensorBoard, including:
# * Metrics summary plots
# * Training graph visualization
# * Activation histograms
# * Sampled profiling
#
# If you have installed TensorFlow with pip, you should be able
# to launch TensorBoard from the command line:
#
# ```sh
# tensorboard --logdir=path_to_your_logs
# ```
#
# You can find more information about TensorBoard
# [here](https://www.tensorflow.org/tensorboard/).
#
#     Arguments:
#         log_dir: the path of the directory where to save the log files to be
#           parsed by TensorBoard.
#         histogram_freq: frequency (in epochs) at which to compute activation and
#           weight histograms for the layers of the model. If set to 0, histograms
#           won't be computed. Validation data (or split) must be specified for
#           histogram visualizations.
#         write_graph: whether to visualize the graph in TensorBoard. The log file
#           can become quite large when write_graph is set to True.
#         write_images: whether to write model weights to visualize as image in
#           TensorBoard.
#         update_freq: `'batch'` or `'epoch'` or integer. When using `'batch'`,
#           writes the losses and metrics to TensorBoard after each batch. The same
#           applies for `'epoch'`. If using an integer, let's say `1000`, the
#           callback will write the metrics and losses to TensorBoard every 1000
#           samples. Note that writing too frequently to TensorBoard can slow down
#           your training.
#         profile_batch: Profile the batch to sample compute characteristics. By
#           default, it will profile the second batch. Set profile_batch=0 to
#           disable profiling. Must run in TensorFlow eager mode.
#         embeddings_freq: frequency (in epochs) at which embedding layers will
#           be visualized. If set to 0, embeddings won't be visualized.

# %%
from datetime import datetime

# %%
datetime.now().strftime("%Y-%m-%d--%H%M")
# Out:
# '2023-08-01--1530'

# %%
# WINDOWS: Use "logs\\fit"
# MACOS/LINUX: Use "logs\fit"

log_directory = '/content/log'

# OPTIONAL: ADD A TIMESTAMP FOR UNIQUE FOLDER
# timestamp = datetime.now().strftime("%Y-%m-%d--%H%M")
# log_directory = log_directory + '\\' + timestamp


board = TensorBoard(log_dir=log_directory,histogram_freq=1,
    write_graph=True,
    write_images=True,
    update_freq='epoch',
    profile_batch=2,
    embeddings_freq=1)

# %% [markdown]
# Now create the model layers:

# %%
model = Sequential()
model.add(Dense(units=30,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=15,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=1,activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam')

# %% [markdown]
# ## Train the Model

# %%
model.fit(x=X_train,
          y=y_train,
          epochs=600,
          validation_data=(X_test, y_test), verbose=1,
          callbacks=[early_stop,board]
          )
# Out:
# Epoch 1/600
# 14/14 [==============================] - 3s 76ms/step - loss: 0.7050 - val_loss: 0.6798
# Epoch 2/600
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6900 - val_loss: 0.6598
# Epoch 3/600
# 14/14 [==============================] - 0s 18ms/step - loss: 0.6613 - val_loss: 0.6451
# Epoch 4/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.6672 - val_loss: 0.6312
# Epoch 5/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.6316 - val_loss: 0.6142
# Epoch 6/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.
600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1277 - val_loss: 0.0898
# Epoch 81/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1352 - val_loss: 0.0851
# Epoch 82/600
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1418 - val_loss: 0.1063
# Epoch 83/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1365 - val_loss: 0.0994
# Epoch 84/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1187 - val_loss: 0.0876
# Epoch 85/600
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1051 - val_loss: 0.0967
# Epoch 86/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1219 - val_loss: 0.0863
# Epoch 87/600
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1289 - val_loss: 0.0876
# Epoch 88/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1034 - val_loss: 0.0973
# Epoch 89/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1279 - val_loss: 0.0874
# Epoch 90/600
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1076 - val_loss: 0.0833
# Epoch 91/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1092 - val_loss: 0.0844
# Epoch 92/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1184 - val_loss: 0.0881
# Epoch 93/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1100 - val_loss: 0.0840
# Epoch 94/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1254 - val_loss: 0.0920
# Epoch 95/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0925 - val_loss: 0.0874
# Epoch 96/600
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0977 - val_loss: 0.0844
# Epoch 97/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1361 - val_loss: 0.1067
# Epoch 98/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1164 - val_loss: 0.0884
# Epoch 99/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1255 - val_loss: 0.0942
# Epoch 100/600
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1128 - val_loss: 0.0876
# Epoch 101/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1052 - val_loss: 0.0871
# Epoch 102/600
# 14/14 [==============================] - 0s 7ms/step - loss: 0.1071 - val_loss: 0.1149
# Epoch 103/600
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0953 - val_loss: 0.1003
# Epoch 104/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0838 - val_loss: 0.0952
# Epoch 105/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1193 - val_loss: 0.0915
# Epoch 106/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1160 - val_loss: 0.0859
# Epoch 107/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0986 - val_loss: 0.1025
# Epoch 108/600
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1160 - val_loss: 0.0854
# Epoch 109/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0870 - val_loss: 0.0804
# Epoch 110/600
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1041 - val_loss: 0.0892
# Epoch 111/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1079 - val_loss: 0.0918
# Epoch 112/600
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0939 - val_loss: 0.1012
# Epoch 113/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0879 - val_loss: 0.0959
# Epoch 114/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0894 - val_loss: 0.1061
# Epoch 115/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1098 - val_loss: 0.1073
# Epoch 116/600
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0884 - val_loss: 0.0852
# Epoch 117/600
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1229 - val_loss: 0.0765
# Epoch 118/600
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1013 - val_loss: 0.0991
# Epoch 119/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1026 - val_loss: 0.0904
# Epoch 120/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0801 - val_loss: 0.0848
# Epoch 121/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0918 - val_loss: 0.0936
# Epoch 122/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0894 - val_loss: 0.0880
# Epoch 123/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0918 - val_loss: 0.0894
# Epoch 124/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0903 - val_loss: 0.0981
# Epoch 125/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0960 - val_loss: 0.1121
# Epoch 126/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1033 - val_loss: 0.0838
# Epoch 127/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0921 - val_loss: 0.0876
# Epoch 128/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0974 - val_loss: 0.0849
# Epoch 129/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0896 - val_loss: 0.0912
# Epoch 130/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0932 - val_loss: 0.0943
# Epoch 131/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0904 - val_loss: 0.0800
# Epoch 132/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0899 - val_loss: 0.0910
# Epoch 133/600
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0977 - val_loss: 0.0908
# Epoch 134/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1014 - val_loss: 0.0827
# Epoch 135/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1060 - val_loss: 0.0836
# Epoch 136/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1067 - val_loss: 0.0851
# Epoch 137/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1108 - val_loss: 0.0868
# Epoch 138/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0834 - val_loss: 0.0919
# Epoch 139/600
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0904 - val_loss: 0.1033
# Epoch 140/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0775 - val_loss: 0.0888
# Epoch 141/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0853 - val_loss: 0.0797
# Epoch 142/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0930 - val_loss: 0.0781
# Epoch 142: early stopping

# %% [markdown]
# # Running Tensorboard

# %% [markdown]
# ## Running through the Command Line
#
# **Watch video to see how to run Tensorboard through a command line call.**

# %% [markdown]
# Tensorboard will run locally in your browser at [http://localhost:6006/](http://localhost:6006/)

# %%
print(log_directory)
# Out:
# /content/log

# %%
pwd
# Out:
# '/content'

# %% [markdown]
# ### Use cd at your command line to change directory to the file path reported back by pwd or your current .py file location.
# ### Then run this code at your command line or terminal

# %%
#tensorboard --logdir log/fit
tensorboard --logdir= /content/log
